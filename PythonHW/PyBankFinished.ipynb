# %%
#break things down using mini objectives. Step by step so I can follow

import csv
import os

# %%
#File we are importing data from

PyBankcsv = os.path.join("Resources","budget_data.csv")

# %%
#Store the data I'm using

profit = []
monthly_changes = []
date = []

# %%
#set initial values for everything

count = 0
total_profit = 0
total_change_profits = 0
initial_profit = 0

# %%
#Open the CSV file

with open(PyBankcsv, newline="") as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
    csv_header = next(csvreader)
    
    for row in csvreader: 

#count the number of months which is the first question asked        
      count = count + 1
      date.append(row[0])
      profit.append(row[1])
      total_profit = total_profit + int(row[1])
      final_profit = int(row[1])
      monthly_change_profits = final_profit - initial_profit
    
#store the changes

      monthly_changes.append(monthly_change_profits)

      total_change_profits = total_change_profits + monthly_change_profits
      initial_profit = final_profit
      average_change_profits = (total_change_profits/count)
    
      greatest_increase_profits = max(monthly_changes)
      greatest_decrease_profits = min(monthly_changes)

      increase_date = date[monthly_changes.index(greatest_increase_profits)]
      decrease_date = date[monthly_changes.index(greatest_decrease_profits)]
    
#See if this prints the table correctly *fingers crossed*

      print("Financial Analysis")
      print("----------------------------------------------------------")
      print("Total Months: " + str(count))
      print("Total Profits: " + "$" + str(total_profit))
      print("Average Change: " + "$" + str(int(average_change_profits)))
      print("Greatest Increase in Profits: " + str(increase_date) + " ($" + str(greatest_increase_profits) + ")")
      print("Greatest Decrease in Profits: " + str(decrease_date) + " ($" + str(greatest_decrease_profits)+ ")")
# Out:
# Financial Analysis
# ----------------------------------------------------------
# Total Months: 1
# Total Profits: $867884
# Average Change: $867884
# Greatest Increase in Profits: Jan-2010 ($867884)
# Greatest Decrease in Profits: Jan-2010 ($867884)
# Financial Analysis
# ----------------------------------------------------------
# Total Months: 2
# Total Profits: $1852539
# Average Change: $492327
# Greatest Increase in Profits: Jan-2010 ($867884)
# Greatest Decrease in Profits: Feb-2010 ($116771)
# Financial Analysis
# ----------------------------------------------------------
# Total Months: 3
# Total Profits: $2174552
# Average Change: $107337
# Greatest Increase in Profits: Jan-2010 ($867884)
# Greatest Decrease in Profits: Mar-2010 ($-662642)
# Financial Analysis
# ----------------------------------------------------------
# Total Months: 4
# Total Profits: $2105135
# Average Change: $-17354
# Greatest Increase in Profits: Jan-2010 ($867884)
# ...
